# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# # Data science tools and Ecosystem

# %% [markdown]
# ![2-title-png.png](attachment:10e1ba23-ce3b-4e22-9200-0e0dac1c5ea3.png)

# %% [markdown]
# ![3-intro.png](attachment:300254b1-2080-43db-9410-6fc715e64307.png)

# %% [markdown]
# # Introduction
#
#  In this notebook, Data Science tools and ecosystem are summarized.

# %% [markdown]
# ![4-dslanguages.png](attachment:6b5f5feb-4783-4a8f-835c-bf9167fabf95.png)

# %% [markdown]
# # some of popular language that use data scientists use are;
# 1. *python*
# 2. *sql*
# 3. *R*
# 4. *julia*

# %% [markdown]
# # Some of the commonly used libraries used  by data scientists include:
# 1. **Pandas**
# 2. **Numpy**
# 3. **Metaplotlib**
# 4. **seaborn**
# 5. **Scikit-learn**

# %% [markdown]
# ![5-dislibres.png](attachment:44d638f5-4a52-4a01-86b4-b372cb95574d.png)

# %% [markdown]
# # Data Science tools
# | Data science |
# |Jupyter notebook
# |Rstudio|
# |vs code|

# %% [markdown]
# ![6-dstools.png](attachment:a4c21d29-6ca5-414e-a2de-f766d7687007.png)

# %% [markdown]
# ### Below are  a few  examples of evaluating arithmatic espressions in Python:
# 1. **addition:** 10+20 result in 30
# 2. **subtraction:** 8-4 result in 4
# 3. **Multipiction:** 7*2 result in 14
# 4. **Division:** 6/2 result in 3

# %% [markdown]
# ![7-introarithmetic.png](attachment:de028adb-1fb1-447c-8822-ebe00f69f7cd.png)

# %%
# This a simple arithmetic expression to multipy then add integers
result = (3*4)+5
result
# Out:
# [1] 17

# %% [markdown]
# ![8-multiplyandaddintegers.png](attachment:a6db8e54-d601-428f-a8b4-6b9561a796da.png)

# %% [markdown]
# **Objectives**
# -List data science tools
# -list  popular languages for data science
# -list commonly used libraries in data science
# -Demonstrate arithmatic expressions in python
# -Evaluate simple arithmatic expressions

# %% [markdown]
# ![10-objectives.png](attachment:44465fc2-fd82-4604-99bc-274ead2f552f.png)

# %% [markdown]
# # Author
# Sehajvir singh

# %% [markdown]
# ![11-authordetails.png](attachment:4a964d60-5087-4f22-9aff-363a90167972.png)
